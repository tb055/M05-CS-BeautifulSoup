# %%
# Use of IPython.display and HTML for using css to format text in Markdown based on
# www.dataquest.io/blog/advanced-jupyter-notebooks-tutorial
from IPython.display import HTML
HTML(
    "<style>\
    span.str {color:#BA2121; font-style:italic; font-weight:bold;}\
    span.num {color:#080; font-style:italic; font-weight:bold;}\
    span.bltn {color:#080; font-weight:bold;}\
    span.op {color:#AA22FF;}\
    span.func {color:#00F; font-weight:bold;}\
    h3.yt {color:#009900; font-style:italic;}\
    span.yt {color:#009900; font-style:italic;}</style>"
)
# Out:
# <style>    span.str {color:#BA2121; font-style:italic; font-weight:bold;}    span.num {color:#080; font-style:italic; font-weight:bold;}    span.bltn {color:#080; font-weight:bold;}    span.op {color:#AA22FF;}    span.func {color:#00F; font-weight:bold;}    h3.yt {color:#009900; font-style:italic;}    span.yt {color:#009900; font-style:italic;}</style>

# %% [markdown]
# <h2><b><u>Case Study: Online Data in BeautifulSoup</u></b></h2>
#
# <h3><b><i>Background</i></b></h3>
# It is important to learn how to access data sources that are stored online. Most of the data you've encountered in this course so far was originally found online. In this Case Study, you'll practice accessing <b><i>data hosted online</i></b> using libraries and solutions based on what you've learned from DataCamp's <a href = "https://learn.datacamp.com/courses/intermediate-importing-data-in-python"> Intermediate Importing Data in Python</a>. You'll also expand your knowledge by working with different datasets and the <b><i>Socrata Open Data API</i></b>.
#
# <h3><b><i>Goal</i></b></h3>
# The goal of this Case Study is to become more familiar with accessing <b><i>data hosted online</i></b> using Python. This can be divided into several components.
# <ul>
#     <li>Requesting online resources such as <b><i>webpages</i></b> using <b><i>urllib and requests libraries</i></b>. Working with the request's returned <b><i>HTML</i></b> results using <b><i>BeautifulSoup</i></b>.</li>
#     <li>Requesting online resources through a <b><i>REST endpoint</i></b> using the <b><i>requests</i></b> library. Working with the returned <b><i>JSON</i></b> result using <b><i>pandas</i></b>.</li>
#     <li>Requesting online resources through a <b><i>REST endpoint</i></b> using <b><i>urlopen</i></b>. Working with the returned <b><i>file-type data</i></b> and converting it to a <b><i>pandas DataFrame</i></b>.</li>
#     <li>Using an <b><i>API</i></b> to access a dataset. You will use the <b><i>Socrata Open Data API</i></b> and the <b><i>sodapy</i></b> library to access the data.</li>
# </ul>
#
# <h3><b><i>Data</i></b></h3>
# You will work with two different data resources in this Case Study. The first is the <b><i>University of Arkansas's Undergraduate Catalog Data Science (DTSC) webpage</i></b> [1]. The second is <b><i>New York State Energy Research and Development Authority (NYSERDA) Estimated Gasoline Sales: Beginning 1995 dataset</i></b> [2]. This dataset contains the estimated yearly amount of gasoline sales by thousands of gallons per county in New York. You will download the <b><i>Estimated Gasoline Sales</i></b> data in <b><i>JSON</i></b> format, practice extracting and formatting the necessary data from the <b><i>JSON object</i></b>, and analyze this data. You will also practice using <b><i>APIs</i></b> by accessing the <b><i>Estimated Gasoline Sales</i></b> data through its <b><i>Socrata Open Data API</i></b> endpoint. The <b><i>Socrata Open Data API</i></b> is chosen for this Case Study because it does not require you to sign up for an <b><i>API key</i></b> to access public data through it.
#
# <h3><b><i>Additional Requirements</i></b></h3>
# If you do not already have the <b><i>sodapy</i></b> Python library installed, you will need to install it using <b><i>pip</i></b>. Installation instructions can be found at <a href="https://pypi.org/project/sodapy/">PyPi</a>.
#
# Sources:
# <ol style = "font-size:8px">
#     <li>University of Arkansas. 2021. Data Science (DTSC). 2021-2022 Catalog. https://catalog.uark.edu/undergraduatecatalog/collegesandschools/interdisciplinarystudies/datasciencedasc/. </li>
#     <li>New York State Energy Research and Development Authority. 2021. "Estimated Gasoline Sales: Beginning 1995". https://data.ny.gov/Energy-Environment/Estimated-Gasoline-Sales-Beginning-1995/cwrk-j5nn. </li>
# </ol>

# %% [markdown]
# <h3> Using HTTP and HTML</h3>
# In the section below, you will practice requesting and accessing internet resources through <b><i>HTTP requests</i></b>. We will use two different libraries for this, <b><i>urllib</i></b> and <b><i>requests</i></b>. The <b><i>BeautifulSoup</i></b> package from <b><i>bs4</i></b> will be used to parse and format the <b><i>requests</i></b>.
#
# The <span class="bltn">import</span> statements below have been completed for you. Notice that we will not <span class="bltn">import</span> everything from <b><i>urllib</i></b>. Only the <b><i>Request, URLError</i></b> and <b><i>HTTPError</i></b> classes and the <b><i>urlopen</i></b> function will be used.
#
# <h4><u>Import Statements</i></h4>

# %%
# Import
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError 

import requests
from bs4 import BeautifulSoup

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h4><u>Requesting a URL with Urllib</u></h4>
#
# In the code cell below, a <span class="str">string uark_url</span> is created which specifies the <b><i>url</i></b> to access Data Science page in the University of Arkansas's Undergraduate Catalog. A <b><i>Request</i></b> object is created and <span class = "str">uark_url</span> is passed in the constructor. Next, <b>urlopen</b> is used to send the request to the server and the <b><i>response</i></b> is stored. The contents of the response are then read into a variable <b><i>html_page</i></b> using <b><i>urlopen's</i></b> <b>read</b> method. The <b><i>html_page</i></b> variable is then <span class="bltn">printed</span> and the <b><i>request</i></b> closed using <b><i>urllib's</i></b> <b>close</b> method. It is good practice to close the <b><i>HTTP</i></b> connection when done.
#
# Sometimes there might be an error with how an <b><i>HTTP request</i></b> is formatted or with the server the request is being made to. In order to handle potential errors, <span class="bltn">try and except</span> blocks are used. You do not have to understand the particular errors handled at this point. If interested, more information on <b><i>HTTPError</i></b> and <b><i>URLError</i></b> can be found <a href = "https://docs.python.org/3/howto/urllib2.html#handling-exceptions"> here </a>.
#
# As you practice more with making HTTP requests, it is important to remember to <b><i>avoid spamming a server with multiple repeated requests.</i></b>

# %%
# Try and except error handling based on usage in: https://docs.python.org/3/howto/urllib2.html

# String of the URL to open. 
uark_url = "https://catalog.uark.edu/undergraduatecatalog/collegesandschools/interdisciplinarystudies/datasciencedasc/"

# Create Request object and pass the uark_url to it. 
req = Request(uark_url)

try:
    # Open the url (Send HTTP request) using urlopen(req)
    response = urlopen(req)
    
    # Read in the html page using response.read()
    html_page = response.read()

    # Print the returned response html_page
    # print(html_page)
    # Terminate connection using response.close()
    response.close()
    
except HTTPError as e:
    print("HTTP Error: ", e.code)
except URLError as e:
    print("URL Error: ", e.reason)

# %% [markdown]
# <h4><u>Requesting a URL with Requests and Parsing with Beautiful Soup</u></h4>
#
# In the code below, you will use <b><i>BeautifulSoup</i></b> and <b><i>Request</i></b> libraries to extract data from the web page specified by <span class="str">uark_url</span>. The <b>get</b> method is used to make a <b><i>HTTP GET request</i></b> by passing in the variable <span class="str">uark_url</span>. The variable <b><i>html_page</i></b> stores the response and the <b><i>request</i></b> is closed using the <b>close</b> method.
#
# A <b><i>BeautifulSoup</i></b> object, (<b><i>soup_obj)</i></b>, is created and <b><i>html_page</i></b> is specified as the the <b><i>url response</i></b> to parse. The type of <b><i>parser</i></b> to use is specified as <span class="str">html.parser</span>. This tells the <b><i>BeautifulSoup</i></b> object to parse the response as HTML. Instead of viewing the HTML as one long string, the <b><i>Beautiful Soup class</i></b> <b>prettify</b> method is used to convert the parsed HTML into a human readable format including indentations and new lines.
#
# The <b><i>BeautifulSoup</i></b> code in this Case Study was developed using the <a href = "https://www.crummy.com/software/BeautifulSoup/bs4/doc/"> BeautifulSoup Documentation</a> as reference. The documentation page is a good place to start for finding out how-to use <b><i>BeautifulSoup</i></b> to parse a webpage.

# %%
# Create a HTTP GET request using requests.get() with the uark_url string. Store the returned response in the req variable. 
req = requests.get(uark_url)

# %%
# Begin a new cell to avoid accidentally making the same request multiple times. 
# Access the contents of the response  by specifying text encoding (Hint: .text)
html_page = req.text

# Close the request 
req.close() 

# Create BeautifulSoup object and pass the text response. Hint: BeautifulSoup(html_page, 'html.parser')
soup_obj = BeautifulSoup(html_page, "html.parser")

# Access the BeautifulSoup object's contents and display in an easy-to-read format using .prettify()
pr_soup_obj = soup_obj.prettify()

# Print the prettify() result
print(pr_soup_obj)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xml:lang="en">
#  <head>
#   <title>
#    Data Science (DTSC) &lt; University of Arkansas
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Lk5jLhOJuM7gcjWytiaI2KaOmfRGXrRKxwLrBEUXI_w" name="google-site-verification"/>
#   <meta content="The interdisciplinary Bachelor of Science in Data Science will prepare students for a successful career in data science with options to pursue one of ten concentrations." name="description"/>
#   <meta content="Data Science, data analytics, accounting analytics, bioinformatics, biomedical informatics, healthcare informatics, business data, computational analytics, geospatial data, operations analytics, social data analytics, supply chain analytics, data, DASC, DTSC" name="keywords"/>
#   <link href="/search/opensearch.xml" rel="search" title="Catalog" type="application/opensearchdescription+xml"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/css/reset.css" rel="stylesheet" type="text/css"/>
#   <link href="/fonts/font-awesome/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/courseleaf.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/screen.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/css/handheld.css" media="only screen and (max-width: 777px)" rel="stylesheet" type="text/css"/>
#   <link href="/css/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script src="/js/jquery.js" type="text/javascript">
#   </script>
#   <script src="/js/lfjs.js" type="text/javascript">
#   </script>
#   <script src="/js/lfjs_any.js" type="text/javascript">
#   </script>
#   <link href="/js/lfjs.css" rel="stylesheet" type="text/css"/>
#   <script src="/js/courseleaf.js" type="text/javascript">
#   </script>
#   <script src="/js/custom.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var gakey = "UA-127684-2";
#   </script>
#   <script src="/js/analytics.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <!--htdig_noindex-->
#   <nav class="accessible noscript">
#    <div class="accessible-menu">
#     <ul>
#      <li>
#       <a href="#content" rel="section" title="Skip to Content">
#        Skip to Content
#       </a>
#      </li>
#      <li>
#       <a href="/azindex/" title="AZ Index">
#        AZ Index
#       </a>
#      </li>
#      <li>
#       <a href="/" title="Catalog Home">
#        Catalogue Home
#       </a>
#      </li>
#     </ul>
#    </div>
#   </nav>
#   <!--/htdig_noindex-->
#   <!--htdig_noindex-->
#   <header class="clearfix" id="header">
#    <div class="wrap">
#     <div id="logo">
#      <a href="http://www.uark.edu">
#       University of Arkansas
#      </a>
#     </div>
#     <!--end #logo-->
#     <div class="clearfix" id="head-top">
#      <h1>
#       <a href="/">
#        2022-23 Catalog
#       </a>
#      </h1>
#      <div id="head-right">
#       <div id="search">
#        <form action="/search/" class="clearfix" id="cl-search" role="search">
#         <input name="edition" type="hidden" value="2022-23"/>
#         <label for="name">
#          Search Catalog
#         </label>
#         <input class="searchbox" id="name" name="P" size="25" type="text"/>
#         <input class="submit" type="submit" value="Search"/>
#        </form>
#       </div>
#       <!--end #search-->
#       <div id="top-menu">
#        <a href="#" id="menu">
#         Links to important University of Arkansas pages
#        </a>
#        <nav aria-label="Seconday Navigation" id="dropdown" role="navigation">
#         <h3>
#          University of Arkansas
#         </h3>
#         <ul>
#          <li>
#           <a href="http://www.uark.edu/a-to-z.php">
#            A-Z Index
#           </a>
#          </li>
#          <li>
#           <a href="https://learn.uark.edu">
#            Bb Learn
#           </a>
#          </li>
#          <li>
#           <a href="http://campusmaps.uark.edu/">
#            Campus Map
#           </a>
#          </li>
#          <li>
#           <a href="http://UAConnect.uark.edu">
#            UAConnect
#           </a>
#          </li>
#          <li>
#           <a href="http://directory.uark.edu/">
#            Directory
#           </a>
#          </li>
#          <li>
#           <a href="http://email.uark.edu/">
#            UARK Gmail
#           </a>
#          </li>
#          <li>
#           <a href="http://exchange.uark.edu/">
#            Exchange Mail
#           </a>
#          </li>
#          <li>
#           <a href="http://webbasis.uark.edu/">
#            webBASIS
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <!--end #dropdown-->
#       </div>
#       <!--end #top-menu-->
#      </div>
#      <!--end #head-right-->
#     </div>
#     <!--end #head-top-->
#    </div>
#    <!--end .wrap-->
#   </header>
#   <!--end #header-->
#   <!--/htdig_noindex-->
#   <!--htdig_noindex-->
#   <nav aria-label="Seconday Navigation" class="clearfix" id="navigation">
#    <div class="wrap">
#     <ul>
#      <li>
#       <a href="/">
#        Home
#       </a>
#      </li>
#      <li>
#       <a href="/generalinfo/">
#        General Info
#       </a>
#      </li>
#      <li>
#       <a href="/undergraduatecatalog/">
#        Undergraduate Catalog
#       </a>
#      </li>
#      <li>
#       <a href="/graduatecatalog/">
#        Graduate Catalog
#       </a>
#      </li>
#      <li>
#       <a href="/lawcatalog/">
#        Law Catalog
#       </a>
#      </li>
#      <li>
#       <a href="/archives/" target="_blank">
#        Archives
#       </a>
#      </li>
#      <li>
#       <a href="#print-dialog" onclick="showPrintDialog(); return false;">
#        Print
#       </a>
#      </li>
#     </ul>
#    </div>
#    <!--end .wrap-->
#   </nav>
#   <!--end #navigation-->
#   <!--/htdig_noindex-->
#   <div id="wrapper">
#    <div class="clearfix" id="container">
#     <div id="nav-col" role="complementary">
#      <div class="clearfix" id="cl-menu-control">
#       <a class="cl-menu-btn" href="#">
#        Catalog Menu
#       </a>
#      </div>
#      <!--end #cl-menu-control-->
#      <div id="cl-menu" role="navigation">
#       <!-- Begin Nav -->
#       <ul class="nav levelone" id="/undergraduatecatalog/">
#        <li>
#         <a href="/undergraduatecatalog/contactinformation/">
#          Contact Information
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/fieldsofstudy/">
#          Programs of Study
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/enrollmentservices/">
#          Enrollment Services
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/financialaidandscholarships/">
#          Financial Aid and Scholarships
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/orientationandregistration/">
#          Registration
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/feeandcosts/">
#          Fees &amp;​ Cost Estimates
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/academicregulations/">
#          Academic Regulations
#         </a>
#        </li>
#        <li class="active">
#         <a href="/undergraduatecatalog/collegesandschools/">
#          Colleges and Schools
#         </a>
#         <ul class="nav leveltwo" id="/undergraduatecatalog/collegesandschools/">
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/honorscollege/">
#            Honors College
#           </a>
#          </li>
#          <li class="active">
#           <a href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/">
#            Interdisciplinary Studies
#           </a>
#           <ul class="nav levelthree" id="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/">
#            <li class="active self">
#             <a href="#" onclick="return false;">
#              Data Science (DTSC)
#             </a>
#            </li>
#            <li>
#             <a href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/englishlanguageculturalstudieselac/">
#              English Language and Cultural Studies (ELAC)
#             </a>
#            </li>
#            <li>
#             <a href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/nanotechnologynanom/">
#              Nanotechnology (NANO)
#             </a>
#            </li>
#            <li>
#             <a href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/planningplan/">
#              Urban and Regional Planning (PLAN)
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/dalebumperscollegeofagriculturalfoodandlifesciences/">
#            Dale Bumpers College of Agricultural, Food and Life Sciences
#           </a>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/fayjonesschoolofarchitecture/">
#            Fay Jones School of Architecture and Design
#           </a>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/jwilliamfulbrightcollegeofartsandsciences/">
#            Fulbright College of Arts and Sciences
#           </a>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/sammwaltoncollegeofbusiness/">
#            Sam M. Walton College of Business
#           </a>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/collegeofeducationandhealthprofessions/">
#            College of Education and Health Professions
#           </a>
#          </li>
#          <li>
#           <a href="/undergraduatecatalog/collegesandschools/collegeofengineering/">
#            College of Engineering
#           </a>
#          </li>
#          <li>
#           <a href="/lawcatalog/">
#            School of Law
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/reserveofficertrainingcorps/">
#          ROTC
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/servicelearning/">
#          Service Learning
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/faculty/">
#          Undergraduate Faculty
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/coursesofinstruction/">
#          Courses of Instruction
#         </a>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/glossary/">
#          Glossary
#         </a>
#        </li>
#       </ul>
#       <!-- End Nav -->
#      </div>
#      <!--end #cl-menu-->
#     </div>
#     <!--end #nav-col-->
#     <div id="content-col">
#      <!--htdig_noindex-->
#      <!--/htdig_noindex-->
#      <h1>
#       Data Science (DTSC)
#      </h1>
#      <!--htdig_noindex-->
#      <div class="clearfix" id="breadcrumb" role="navigation">
#       <ul>
#        <li>
#         <a href="/">
#          Catalog Home
#         </a>
#         <span class="crumbsep">
#          &gt;
#         </span>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/">
#          Undergraduate Catalog
#         </a>
#         <span class="crumbsep">
#          &gt;
#         </span>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/collegesandschools/">
#          Colleges and Schools
#         </a>
#         <span class="crumbsep">
#          &gt;
#         </span>
#        </li>
#        <li>
#         <a href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/">
#          Interdisciplinary Studies
#         </a>
#         <span class="crumbsep">
#          &gt;
#         </span>
#        </li>
#        <li>
#         <span class="active">
#          Data Science (DTSC)
#         </span>
#        </li>
#       </ul>
#      </div>
#      <!-- end #breadcrumb -->
#      <!--/htdig_noindex-->
#      <div id="sidebar">
#       <script type="text/javascript">
#        //<![CDATA[
# 	var defshow = "text";
# 	var bodycontainer = "#body";
# 	var validhashes = ",text,bswithaccountinganalyticsconcentrationtext,bswithbioinformaticsconcentrationtext,bswithbiomedicalandhealthcareinformaticstext,bswithbusinessdataanalyticsconcentrationtext,bswithcomputationalanalyticsconcentrationtext,bswithcybersecuritydataanalyticsconcentrationtext,bswithdatascienceanalyticsconcentrationtext,bswithgeospatialdataanalyticsconcentrationtext,bswithoperationsanalyticsconcentrationtext,bswithsocialdataanalyticsconcentrationtext,bswithsupplychainanalyticsconcentrationtext,facultytext,courseinventory,";
#
# if(window.location.hash.length) {
# 	var hash = cleanHash(window.location.hash);
# 	if(validhashes.indexOf("," + hash + ",") != -1)
# 		defshow = hash;
# }
# var ss = document.styleSheets;
# var workss = null;
# for(var i=0; i < ss.length; i++) {
# 	var currmedia = "";
# 	if (typeof ss[i].media == "string")
# 		currmedia = ss[i].media
# 	else if (typeof ss[i].media == "object" && ss[i].media.mediaText)
# 		currmedia = ss[i].media.mediaText;
#
# 	if((currmedia == "screen" || currmedia == "all") && (ss[i].href.indexOf("/") == 0 || ss[i].href.indexOf(document.location.host) >= 0)) {
# 		workss = ss[i];
# 		break;
# 	}
# }
# if(workss && workss.insertRule) {
# 	workss.insertRule(".tab_content { display: none; }", workss.cssRules.length)
# 	workss.insertRule(".sectionheader { display: none; }", workss.cssRules.length)
# 	workss.insertRule("#" + defshow + "container { display: block; }", workss.cssRules.length)
# } else if(workss && workss.addRule) {
# 	workss.addRule(".tab_content", "display: none");
# 	workss.addRule(".sectionheader", "display: none");
# 	workss.addRule("#" + defshow + "container", "display: block");
# }
# else {
# 	if (window.console)
# 		window.console.log('screen.css <link> needs attribute media="screen"');
# }
# //]]>
#       </script>
#       <nav aria-label="Page content tabs" id="tabs">
#        <ul class="clearfix" role="tablist">
#         <li id="texttab" role="presentation">
#          <a aria-controls="textcontainer" href="#textcontainer" onclick="return showSection('text');" role="tab">
#           Overview
#          </a>
#         </li>
#         <li id="bswithaccountinganalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithaccountinganalyticsconcentrationtextcontainer" href="#bswithaccountinganalyticsconcentrationtextcontainer" onclick="return showSection('bswithaccountinganalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Accounting Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithbioinformaticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithbioinformaticsconcentrationtextcontainer" href="#bswithbioinformaticsconcentrationtextcontainer" onclick="return showSection('bswithbioinformaticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Bioinformatics Concentration
#          </a>
#         </li>
#         <li id="bswithbiomedicalandhealthcareinformaticstexttab" role="presentation">
#          <a aria-controls="bswithbiomedicalandhealthcareinformaticstextcontainer" href="#bswithbiomedicalandhealthcareinformaticstextcontainer" onclick="return showSection('bswithbiomedicalandhealthcareinformaticstext');" role="tab">
#           Requirements for B.S. with Biomedical and Healthcare Informatics Concentration
#          </a>
#         </li>
#         <li id="bswithbusinessdataanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithbusinessdataanalyticsconcentrationtextcontainer" href="#bswithbusinessdataanalyticsconcentrationtextcontainer" onclick="return showSection('bswithbusinessdataanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Business Data Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithcomputationalanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithcomputationalanalyticsconcentrationtextcontainer" href="#bswithcomputationalanalyticsconcentrationtextcontainer" onclick="return showSection('bswithcomputationalanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Computational Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithcybersecuritydataanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithcybersecuritydataanalyticsconcentrationtextcontainer" href="#bswithcybersecuritydataanalyticsconcentrationtextcontainer" onclick="return showSection('bswithcybersecuritydataanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Cybersecurity Data Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithdatascienceanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithdatascienceanalyticsconcentrationtextcontainer" href="#bswithdatascienceanalyticsconcentrationtextcontainer" onclick="return showSection('bswithdatascienceanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Data Science Statistics Concentration
#          </a>
#         </li>
#         <li id="bswithgeospatialdataanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithgeospatialdataanalyticsconcentrationtextcontainer" href="#bswithgeospatialdataanalyticsconcentrationtextcontainer" onclick="return showSection('bswithgeospatialdataanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Geospatial Data Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithoperationsanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithoperationsanalyticsconcentrationtextcontainer" href="#bswithoperationsanalyticsconcentrationtextcontainer" onclick="return showSection('bswithoperationsanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Operations Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithsocialdataanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithsocialdataanalyticsconcentrationtextcontainer" href="#bswithsocialdataanalyticsconcentrationtextcontainer" onclick="return showSection('bswithsocialdataanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Social Data Analytics Concentration
#          </a>
#         </li>
#         <li id="bswithsupplychainanalyticsconcentrationtexttab" role="presentation">
#          <a aria-controls="bswithsupplychainanalyticsconcentrationtextcontainer" href="#bswithsupplychainanalyticsconcentrationtextcontainer" onclick="return showSection('bswithsupplychainanalyticsconcentrationtext');" role="tab">
#           Requirements for B.S. with Supply Chain Analytics Concentration
#          </a>
#         </li>
#         <li id="facultytexttab" role="presentation">
#          <a aria-controls="facultytextcontainer" href="#facultytextcontainer" onclick="return showSection('facultytext');" role="tab">
#           Faculty
#          </a>
#         </li>
#         <li id="courseinventorytab" role="presentation">
#          <a aria-controls="courseinventorycontainer" href="#courseinventory" onclick="return showSection('courseinventory');" role="tab">
#           Courses
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <div class="narrow" id="content" role="main">
#       <div aria-labelledby="texttab" class="page_content tab_content" id="textcontainer" role="tabpanel">
#        <p>
#         Manuel Rossetti
#         <br/>
#         Director
#         <br/>
#         Bell Engineering 4164
#         <br/>
#         479-575-6756
#         <br/>
#         Email:
#         <a href="mailto:rossetti@uark.edu">
#          rossetti@uark.edu
#         </a>
#        </p>
#        <p>
#         Karl D. Schubert
#         <br/>
#         Associate Director
#         <br/>
#         J.B. Hunt Center 111
#         <br/>
#         479-575-2264
#         <br/>
#         Email:
#         <a href="mailto:karl.schubert@uark.edu">
#          karl.schubert@uark.edu
#         </a>
#        </p>
#        <p>
#         Lee Shoultz
#         <br/>
#         Project/Program Specialist
#         <br/>
#         J.B. Hunt Center 110
#         <br/>
#         479-575-5469
#         <br/>
#         Email:
#         <a href="mailto:eshoultz@uark.edu">
#          eshoultz@uark.edu
#         </a>
#        </p>
#        <p>
#         Data scientists make sense of huge sets of data to help businesses, governments, nonprofits and other organizations make smarter decisions. The university's interdisciplinary Bachelor of Science in Data Science will prepare students for a successful career in data science with a strategic skill set, including the ability to:
#        </p>
#        <ul>
#         <li>
#          Use and apply state-of-the-art technologies for data representation, retrieval, manipulation, storage, governance, understanding, analysis, privacy, and security.
#         </li>
#         <li>
#          Develop descriptive, predictive and prescriptive models to abstract complex systems and organizational problems, and to use computational methods to draw data-supported conclusions.
#         </li>
#         <li>
#          Use foundational knowledge and apply critical thinking skills to identify and solve problems, make decisions, and visualize data, all with an awareness of societal and ethical impacts.
#         </li>
#         <li>
#          Adapt analytics concepts to interpret and communicate findings and implications to senior decision-makers.
#         </li>
#         <li>
#          Work effectively in an interdisciplinary team and transfer findings between knowledge domains and to others with no domain experience.
#         </li>
#         <li>
#          Communicate using technical and non-technical language in writing and verbally.
#         </li>
#        </ul>
#        <p>
#         Three colleges at the university — the College of Engineering, the Fulbright College of Arts and Sciences, and the Sam M. Walton College of Business — contribute expertise to the overall major while providing deeper insight into the concentrations they offer, including:
#        </p>
#        <ul>
#         <li>
#          Accounting Analytics
#         </li>
#         <li>
#          Bioinformatics
#         </li>
#         <li>
#          Biomedical and Healthcare Informatics
#         </li>
#         <li>
#          Business Data Analytics
#         </li>
#         <li>
#          Computational Analytics
#         </li>
#         <li>
#          Cybersecurity Analytics
#         </li>
#         <li>
#          Data Science Statistics
#         </li>
#         <li>
#          Geospatial Data Analytics
#         </li>
#         <li>
#          Operations Analytics
#         </li>
#         <li>
#          Social Data Analytics
#         </li>
#         <li>
#          Supply Chain Analytics
#         </li>
#        </ul>
#       </div>
#       <!--end #textcontainer -->
#       <div aria-labelledby="bswithaccountinganalyticsconcentrationtexttab" class="page_content tab_content" id="bswithaccountinganalyticsconcentrationtextcontainer" role="tabpanel">
#        <a name="bswithaccountinganalyticsconcentrationtext">
#        </a>
#        <h3 class="steph1">
#         Requirements for B.S. in Data Science with Accounting Analytics Concentration
#        </h3>
#        <p>
#         Below are the general requirements for a Bachelor of Science degree with a major in Data Science, followed by specific requirements for the Accounting Analytics Concentration. Below those is a recommended eight-semester plan to achieve those requirements in a timely fashion.
#        </p>
#        <p>
#         <strong>
#          Requirements for B.S. in Data Science
#         </strong>
#        </p>
#        <p>
#         Each student in Data Science is required to complete 120 hours of coursework including the
#         <a href="/undergraduatecatalog/gened/stateminimum/">
#          state minimum core
#         </a>
#         . To be eligible for graduation, all students must complete at least 60 hours of Data Science (DTSC) Core required classes at the University of Arkansas. Each student in Data Science is also required to complete an additional 20-21 hours (depending on the student's chosen concentration) of required and elective concentration courses to meet the requirements for a concentration.
#        </p>
#        <p>
#         Additional opportunities are available to enhance the educational experience of students in these areas.  Students should consult their academic adviser for recommendations.
#        </p>
#        <table class="sc_courselist" width="100%">
#         <colgroup>
#          <col class="codecol"/>
#          <col class="titlecol"/>
#          <col align="char" char="." class="hourscol"/>
#         </colgroup>
#         <tbody>
#          <tr class="even areaheader firstrow">
#           <td colspan="2">
#            <span class="courselistcomment areaheader">
#             State Minimum Core and General Education (36 hours)
#            </span>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ENGL%201013" onclick="return showCourse(this, 'ENGL 1013');" title="ENGL 1013">
#             ENGL 1013
#            </a>
#           </td>
#           <td>
#            Composition I (ACTS Equivalency = ENGL 1013)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ENGL%201033" onclick="return showCourse(this, 'ENGL 1033');" title="ENGL 1033">
#             ENGL 1033
#            </a>
#           </td>
#           <td>
#            Technical Composition II (ACTS Equivalency = ENGL 1023)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=MATH%202554" onclick="return showCourse(this, 'MATH 2554');" title="MATH 2554">
#             MATH 2554
#            </a>
#           </td>
#           <td>
#            Calculus I (ACTS Equivalency = MATH 2405)
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Science state minimum electives (two courses with labs)
#            </span>
#           </td>
#           <td class="hourscol">
#            8
#           </td>
#          </tr>
#          <tr class="odd">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Fine Arts state minimum core
#            </span>
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Humanities state minimum core
#            </span>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=PHIL%203103" onclick="return showCourse(this, 'PHIL 3103');" title="PHIL 3103">
#             PHIL 3103
#            </a>
#           </td>
#           <td>
#            Ethics and the Professions
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             U.S. History and Government state minimum core
#            </span>
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=HIST%202003" onclick="return showCourse(this, 'HIST 2003');" title="HIST 2003">
#              HIST 2003
#             </a>
#            </div>
#           </td>
#           <td>
#            History of the American People to 1877 (ACTS Equivalency = HIST 2113)
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="orclass odd">
#           <td class="codecol orclass">
#            <div style="margin-left: 20px;">
#             or
#             <a class="bubblelink code" href="/search/?P=HIST%202013" onclick="return showCourse(this, 'HIST 2013');" title="HIST 2013">
#              HIST 2013
#             </a>
#            </div>
#           </td>
#           <td colspan="2">
#            History of the American People, 1877 to Present (ACTS Equivalency = HIST 2123)
#           </td>
#          </tr>
#          <tr class="orclass odd">
#           <td class="codecol orclass">
#            <div style="margin-left: 20px;">
#             or
#             <a class="bubblelink code" href="/search/?P=PLSC%202003" onclick="return showCourse(this, 'PLSC 2003');" title="PLSC 2003">
#              PLSC 2003
#             </a>
#            </div>
#           </td>
#           <td colspan="2">
#            American National Government (ACTS Equivalency = PLSC 2003)
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Social Science state minimum core electives
#            </span>
#           </td>
#           <td class="hourscol">
#            6
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ECON%202143" onclick="return showCourse(this, 'ECON 2143');" title="ECON 2143">
#             ECON 2143
#            </a>
#           </td>
#           <td>
#            Basic Economics: Theory and Practice (represents 3 of the 9 required credit hours for Social Science elective)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even areaheader">
#           <td colspan="2">
#            <span class="courselistcomment areaheader">
#             Data Science Required Core (47 hours)
#            </span>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%201001" onclick="return showCourse(this, 'DASC 1001');" title="DASC 1001">
#             DASC 1001
#            </a>
#           </td>
#           <td>
#            Introduction to Data Science (First-Year Program - Introduction to Data Science)
#           </td>
#           <td class="hourscol">
#            1
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%201104" onclick="return showCourse(this, 'DASC 1104');" title="DASC 1104">
#             DASC 1104
#            </a>
#           </td>
#           <td>
#            Programming Languages for Data Science (Programming Languages for Data Science (R, Python))
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%201204" onclick="return showCourse(this, 'DASC 1204');" title="DASC 1204">
#             DASC 1204
#            </a>
#           </td>
#           <td>
#            Introduction to Object Oriented Programming for Data Science (Introduction to Object Oriented Programming for Data Science (JAVA))
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%202594" onclick="return showCourse(this, 'DASC 2594');" title="DASC 2594">
#             DASC 2594
#            </a>
#           </td>
#           <td>
#            Multivariable Math for Data Scientists (Multivariable Math for Data Scientists)
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%201222" onclick="return showCourse(this, 'DASC 1222');" title="DASC 1222">
#             DASC 1222
#            </a>
#           </td>
#           <td>
#            Role of Data Science in Today's World (Role of Data Science in Today's World)
#           </td>
#           <td class="hourscol">
#            2
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%202103" onclick="return showCourse(this, 'DASC 2103');" title="DASC 2103">
#             DASC 2103
#            </a>
#           </td>
#           <td>
#            Data Structures &amp; Algorithms (Data Structures &amp; Algorithms)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%202113" onclick="return showCourse(this, 'DASC 2113');" title="DASC 2113">
#             DASC 2113
#            </a>
#           </td>
#           <td>
#            Principles and Techniques of Data Science (Principles &amp; Techniques of Data Science)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%202203" onclick="return showCourse(this, 'DASC 2203');" title="DASC 2203">
#             DASC 2203
#            </a>
#           </td>
#           <td>
#            Data Management and Data Base (Data Management &amp; Data Base)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%202213" onclick="return showCourse(this, 'DASC 2213');" title="DASC 2213">
#             DASC 2213
#            </a>
#           </td>
#           <td>
#            Data Visualization and Communication (Data Visualization &amp; Communication (Tableau))
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%203103" onclick="return showCourse(this, 'DASC 3103');" title="DASC 3103">
#             DASC 3103
#            </a>
#           </td>
#           <td>
#            Cloud Computing and Big Data (Cloud Computing &amp; Big Data)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%203203" onclick="return showCourse(this, 'DASC 3203');" title="DASC 3203">
#             DASC 3203
#            </a>
#           </td>
#           <td>
#            Optimization Methods in Data Science (Optimization Methods in Data Science)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%203213" onclick="return showCourse(this, 'DASC 3213');" title="DASC 3213">
#             DASC 3213
#            </a>
#           </td>
#           <td>
#            Statistical Learning (Statistical Learning)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%204892" onclick="return showCourse(this, 'DASC 4892');" title="DASC 4892">
#             DASC 4892
#            </a>
#           </td>
#           <td>
#            Data Science Practicum I (Data Science Practicum I)
#           </td>
#           <td class="hourscol">
#            2
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%204113" onclick="return showCourse(this, 'DASC 4113');" title="DASC 4113">
#             DASC 4113
#            </a>
#           </td>
#           <td>
#            Machine Learning (Machine Learning)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%204123" onclick="return showCourse(this, 'DASC 4123');" title="DASC 4123">
#             DASC 4123
#            </a>
#           </td>
#           <td>
#            Social Problems in Data Science and Analytics (Social Problems (Issues) in DASC &amp; Analytics)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=DASC%204993" onclick="return showCourse(this, 'DASC 4993');" title="DASC 4993">
#             DASC 4993
#            </a>
#           </td>
#           <td>
#            Data Science Practicum II (Data Science Practicum II)
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd areaheader">
#           <td colspan="2">
#            <span class="courselistcomment areaheader">
#             Data Science Required Additional Courses
#            </span>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=MATH%202564" onclick="return showCourse(this, 'MATH 2564');" title="MATH 2564">
#             MATH 2564
#            </a>
#           </td>
#           <td>
#            Calculus II (ACTS Equivalency = MATH 2505)
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=SEVI%202053" onclick="return showCourse(this, 'SEVI 2053');" title="SEVI 2053">
#             SEVI 2053
#            </a>
#           </td>
#           <td>
#            Business Foundations
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Choose from one of these two-course sequences
#            </span>
#           </td>
#           <td class="hourscol">
#            6-7
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=STAT%203013" onclick="return showCourse(this, 'STAT 3013');" title="STAT 3013">
#              STAT 3013
#             </a>
#             <br/>
#             <span class="blockindent" style="margin-left:20px;">
#              &amp;
#              <a class="bubblelink code" href="/search/?P=STAT%203003" onclick="return showCourse(this, 'STAT 3003');" title="STAT 3003">
#               STAT 3003
#              </a>
#             </span>
#            </div>
#           </td>
#           <td>
#            Introduction to Probability
#            <br/>
#            <span class="blockindent" style="margin-left:20px;">
#             and Statistical Methods
#            </span>
#            (Statistical Methods)
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <div style="margin-left: 20px;">
#             <span class="courselistcomment commentindent">
#              Or
#             </span>
#            </div>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=INEG%202314" onclick="return showCourse(this, 'INEG 2314');" title="INEG 2314">
#              INEG 2314
#             </a>
#             <br/>
#             <span class="blockindent" style="margin-left:20px;">
#              &amp;
#              <a class="bubblelink code" href="/search/?P=INEG%202323" onclick="return showCourse(this, 'INEG 2323');" title="INEG 2323">
#               INEG 2323
#              </a>
#             </span>
#            </div>
#           </td>
#           <td>
#            Statistics for Industrial Engineers I
#            <br/>
#            <span class="blockindent" style="margin-left:20px;">
#             and Probability and Stochastic Processes for Industrial Engineers
#            </span>
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even areaheader">
#           <td colspan="2">
#            <span class="courselistcomment areaheader">
#             Data Science Concentration Courses
#            </span>
#           </td>
#           <td class="hourscol">
#            20-21
#           </td>
#          </tr>
#          <tr class="odd areaheader lastrow">
#           <td colspan="2">
#            <span class="courselistcomment areaheader">
#             General Electives
#            </span>
#           </td>
#           <td class="hourscol">
#            2-4
#           </td>
#          </tr>
#          <tr class="listsum">
#           <td colspan="2">
#            Total Hours
#           </td>
#           <td class="hourscol">
#            120
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <h3>
#         Required Accounting Analytics Concentration Courses
#        </h3>
#        <table class="sc_courselist" width="100%">
#         <colgroup>
#          <col class="codecol"/>
#          <col class="titlecol"/>
#          <col align="char" char="." class="hourscol"/>
#         </colgroup>
#         <tbody>
#          <tr class="even firstrow">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ACCT%202013" onclick="return showCourse(this, 'ACCT 2013');" title="ACCT 2013">
#             ACCT 2013
#            </a>
#           </td>
#           <td>
#            Accounting Principles
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ACCT%202023" onclick="return showCourse(this, 'ACCT 2023');" title="ACCT 2023">
#             ACCT 2023
#            </a>
#           </td>
#           <td>
#            Accounting Principles II
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ACCT%203533" onclick="return showCourse(this, 'ACCT 3533');" title="ACCT 3533">
#             ACCT 3533
#            </a>
#           </td>
#           <td>
#            Accounting Technology
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ACCT%203543" onclick="return showCourse(this, 'ACCT 3543');" title="ACCT 3543">
#             ACCT 3543
#            </a>
#           </td>
#           <td>
#            Accounting Analytics
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ISYS%204193" onclick="return showCourse(this, 'ISYS 4193');" title="ISYS 4193">
#             ISYS 4193
#            </a>
#           </td>
#           <td>
#            Business Analytics and Visualization
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <a class="bubblelink code" href="/search/?P=ISYS%204293" onclick="return showCourse(this, 'ISYS 4293');" title="ISYS 4293">
#             ISYS 4293
#            </a>
#           </td>
#           <td>
#            Business Intelligence
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="even">
#           <td colspan="2">
#            <span class="courselistcomment">
#             Elective Accounting Analytics Concentration Courses (Select 3 hours)
#            </span>
#           </td>
#           <td class="hourscol">
#            3
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=FINN%203013" onclick="return showCourse(this, 'FINN 3013');" title="FINN 3013">
#              FINN 3013
#             </a>
#            </div>
#           </td>
#           <td>
#            Financial Analysis
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=ECON%203033" onclick="return showCourse(this, 'ECON 3033');" title="ECON 3033">
#              ECON 3033
#             </a>
#            </div>
#           </td>
#           <td>
#            Microeconomic Theory
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=ECON%204743" onclick="return showCourse(this, 'ECON 4743');" title="ECON 4743">
#              ECON 4743
#             </a>
#            </div>
#           </td>
#           <td>
#            Introduction to Econometrics
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=ECON%204753" onclick="return showCourse(this, 'ECON 4753');" title="ECON 4753">
#              ECON 4753
#             </a>
#            </div>
#           </td>
#           <td>
#            Forecasting
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="odd">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=ISYS%204213" onclick="return showCourse(this, 'ISYS 4213');" title="ISYS 4213">
#              ISYS 4213
#             </a>
#            </div>
#           </td>
#           <td>
#            ERP Fundamentals
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="even lastrow">
#           <td class="codecol">
#            <div style="margin-left: 20px;">
#             <a class="bubblelink code" href="/search/?P=MKTG%203433" onclick="return showCourse(this, 'MKTG 3433');" title="MKTG 3433">
#              MKTG 3433
#             </a>
#            </div>
#           </td>
#           <td>
#            Introduction to Marketing
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="listsum">
#           <td colspan="2">
#            Total Hours
#           </td>
#           <td class="hourscol">
#            21
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <h3>
#         Data Science B.S. with Accounting Analytics Concentration
#         <br/>
#         Eight-Semester Program
#        </h3>
#        <table class="sc_plangrid">
#         <tbody>
#          <tr class="plangridyear">
#           <th>
#            First Year
#           </th>
#           <th class="hourscol" colspan="2">
#            Units
#           </th>
#          </tr>
#          <tr class="plangridterm">
#           <th>
#           </th>
#           <th class="hourscol">
#            Fall
#           </th>
#           <th class="hourscol">
#            Spring
#           </th>
#          </tr>
#          <tr class="">
#           <td>
#            <a class="bubblelink code" href="/search/?P=MATH%202554" onclick="return showCourse(this, 'MATH 2554');" title="MATH 2554">
#             MATH 2554
#            </a>
#            Calculus I (ACTS Equivalency = MATH 2405) (Satisfies General Education Outcome 2.1)
#            <sup>
#             1
#            </sup>
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
#          <tr class="">
#           <td>
#            State Minimum Core Natural Science Elective with Lab (Satisfies General Education Outcome 3.4)
#           </td>
#           <td class="hourscol">
#            4
#           </td>
#           <td class="hourscol">
#           </td>
#          </tr>
# ...
#           ,
#           <a class="bubblelink code" href="/search/?P=DASC%203203" onclick="return showCourse(this, 'DASC 3203');" title="DASC 3203">
#            DASC 3203
#           </a>
#           , honors standing and student must be a DTSCBS major. (Typically offered: Fall)
#           <br/>
#           This course is equivalent to
#           <a class="bubblelink code" href="/search/?P=DASC%204113" onclick="return showCourse(this, 'DASC 4113');" title="DASC 4113">
#            DASC 4113
#           </a>
#           .
#           <br/>
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4123.  Social Problems in Data Science and Analytics.  3 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           This course explores the ways data analytics and data science are impacted by or intersect with issues of social justice, poverty and economic inequality, racial and ethnic relations, gender, crime, education, health and healthcare, and other contemporary social problems. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%201222" onclick="return showCourse(this, 'DASC 1222');" title="DASC 1222">
#            DASC 1222
#           </a>
#           and student must be a DTSCBS major. (Typically offered: Fall)
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4533.  Information Retrieval.  3 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Information Retrieval is a course providing expertise in processing unstructured data as a key component of data science. It covers text processing, file structures, ranking algorithms, query processing, and web search. Students will gain hands-on experience developing their own search engine from scratch, using Python, C, C++, or Java on a Linux server and making their search engine web accessible. Note: Prior user-level knowledge of Linux for file and directory management and remote login is required for this course. Corequisite:  Lab component. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%202103" onclick="return showCourse(this, 'DASC 2103');" title="DASC 2103">
#            DASC 2103
#           </a>
#           and student must be a DTSCBS major. (Typically offered: Irregular)
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4892.  Data Science Practicum I.  2 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Application of data science, analytics, business intelligence, data mining, machine learning, and data visualization to existing problems. Data Science techniques using current and relevant software and problem-solving methods are applied to current problems for presentation to management. This is the first semester of the required full-year multi-college interdisciplinary practicum using real-world data to solve real-world problems. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%202113" onclick="return showCourse(this, 'DASC 2113');" title="DASC 2113">
#            DASC 2113
#           </a>
#           ,
#           <a class="bubblelink code" href="/search/?P=DASC%203203" onclick="return showCourse(this, 'DASC 3203');" title="DASC 3203">
#            DASC 3203
#           </a>
#           and student must be a DTSCBS major. Pre- or Corequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%204123" onclick="return showCourse(this, 'DASC 4123');" title="DASC 4123">
#            DASC 4123
#           </a>
#           . (Typically offered: Fall)
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4892H.  Honors Data Science Practicum I.  2 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Application of data science, analytics, business intelligence, data mining, machine learning, and data visualization to existing problems. Data Science techniques using current and relevant software and problem-solving methods are applied to current problems for presentation to management. This is the first semester of the required full-year multi-college interdisciplinary practicum using real-world data to solve real-world problems. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%202113" onclick="return showCourse(this, 'DASC 2113');" title="DASC 2113">
#            DASC 2113
#           </a>
#           ,
#           <a class="bubblelink code" href="/search/?P=DASC%203203" onclick="return showCourse(this, 'DASC 3203');" title="DASC 3203">
#            DASC 3203
#           </a>
#           , and honors standing and student must be a DTSCBS major. Pre- or corequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%204123" onclick="return showCourse(this, 'DASC 4123');" title="DASC 4123">
#            DASC 4123
#           </a>
#           . (Typically offered: Fall)
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 490V.  Special Topics in Data Science.  1-6 Hour.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Special Topics in Data Science is a course for data science topics not covered in other courses. Prerequisite:  Students must be a DTSCBS major and Instructor Permission Only. (Typically offered: Fall, Spring and Summer) May be repeated for up to 9 hours of degree credit.
#           <br/>
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 490VH.  Honors Special Topics in Data Science.  1-6 Hour.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Special Topics in Data Science is a course for data science topics not covered in other courses. Prerequisite:  Honors standing and students must be a DTSCBS major and Instructor Permission Only. (Typically offered: Fall, Spring and Summer) May be repeated for up to 9 hours of degree credit.
#           <br/>
#           This course is equivalent to
#           <a class="bubblelink code" href="/search/?P=DASC%20490V" onclick="return showCourse(this, 'DASC 490V');" title="DASC 490V">
#            DASC 490V
#           </a>
#           .
#           <br/>
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4993.  Data Science Practicum II.  3 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Application of data science, analytics, business intelligence, data mining, machine learning, and data visualization to existing problems. Data Science techniques using current and relevant software and problem-solving methods are applied to current problems for presentation to management. This is the second semester of the required full-year multi-college interdisciplinary practicum using real-world data to solve real-world problems. Corequisite:  Lab component. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%204892" onclick="return showCourse(this, 'DASC 4892');" title="DASC 4892">
#            DASC 4892
#           </a>
#           with a grade of C or better and student must be a DTSCBS major. (Typically offered: Spring)
#           <br/>
#          </p>
#         </div>
#         <div class="courseblock">
#          <p class="courseblocktitle" font-size="7pt">
#           <strong>
#            DASC 4993H.  Honors Data Science Practicum II.  3 Hours.
#           </strong>
#          </p>
#          <p class="courseblockdesc" font-size="7pt">
#           Application of data science, analytics, business intelligence, data mining, machine learning, and data visualization to existing problems. Data Science techniques using current and relevant software and problem-solving methods are applied to current problems for presentation to management. This is the second semester of the required full-year multi-college interdisciplinary practicum using real-world data to solve real-world problems. Corequisite:  Lab component. Prerequisite:
#           <a class="bubblelink code" href="/search/?P=DASC%204892" onclick="return showCourse(this, 'DASC 4892');" title="DASC 4892">
#            DASC 4892
#           </a>
#           with a grade of C or better, and student must be a DTSCBS major, and have honors standing. (Typically offered: Spring)
#           <br/>
#           This course is equivalent to
#           <a class="bubblelink code" href="/search/?P=DASC%204993" onclick="return showCourse(this, 'DASC 4993');" title="DASC 4993">
#            DASC 4993
#           </a>
#           .
#           <br/>
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!--end #content-->
#     </div>
#     <!--end #content-col-->
#    </div>
#    <!--end #container-->
#   </div>
#   <!--end #wrapper-->
#   <!--htdig_noindex-->
#   <div id="footer" role="contentinfo">
#    <div class="wrap">
#     <div class="clearfix" id="foot-top">
#      <div id="foot-top-left">
#       <img alt="University of Arkansas" src="/gallery/ua-webfooter.png"/>
#       <ul>
#        <li>
#         <a href="http://www.uark.edu/admissions/index.php">
#          Admissions
#         </a>
#        </li>
#        <li>
#         <a href="http://www.uark.edu/academics/index.php">
#          Academics
#         </a>
#        </li>
#        <li>
#         <a href="http://www.uark.edu/campus-life/index.php">
#          Campus Life
#         </a>
#        </li>
#        <li>
#         <a href="http://www.uark.edu/research/index.php">
#          Research
#         </a>
#        </li>
#        <li>
#         <a href="http://www.uark.edu/athletics/index.php">
#          Athletics
#         </a>
#        </li>
#        <li>
#         <a href="http://www.uark.edu/about/index.php">
#          About
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!--end #foot-top-left-->
#      <div id="social">
#       <ul>
#        <li class="facebook">
#         <a href="https://www.facebook.com/UofArkansas">
#          Like us on Facebook
#         </a>
#        </li>
#        <li class="twitter">
#         <a href="http://twitter.com/uarkansas">
#          Follow us on Twitter
#         </a>
#        </li>
#        <li class="youtube">
#         <a href="http://www.youtube.com/user/UniversityArkansas">
#          Watch us on YouTube
#         </a>
#        </li>
#        <li class="instagram">
#         <a href="http://instagram.com/uarkansas">
#          See us on Instagram
#         </a>
#        </li>
#        <li class="google">
#         <a href="https://plus.google.com/104159281704656057709">
#          Connect with us on Google+
#         </a>
#        </li>
#        <li class="pinterest">
#         <a href="http://pinterest.com/uofaadmissions/">
#          Join us on Pinterest
#         </a>
#        </li>
#        <li class="linkedin">
#         <a href="http://www.linkedin.com/company/university-of-arkansas">
#          Connect with us on LinkedIn
#         </a>
#        </li>
#        <li class="foursquare">
#         <a href="https://foursquare.com/uarkansas">
#          Find us on FourSquare
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!--end #social-->
#     </div>
#     <!--end #foot-top-->
#     <hr/>
#     <div class="clearfix" id="foot-mid">
#      <div id="address">
#       <p>
#        Fayetteville, AR 72701
#        <br/>
#        479-575-2000
#       </p>
#       <a href="http://campusmaps.uark.edu/" title="View Campus Maps">
#        <img alt="Map of University of Arkansas Campus" src="/images/map.png"/>
#       </a>
#      </div>
#      <!--end #address-->
#      <div id="news-events">
#       <div id="news">
#        <h4>
#         <a href="http://news.uark.edu/" title="Arkansas Newswire">
#          NEWS
#         </a>
#        </h4>
#        <ul id="news-list">
#        </ul>
#        <script defer="">
#         $(function () {
# 							parseNews('//campusdata.uark.edu/apiv2/articles/articlesCommon?$orderby=publishDate+desc&$filter=Commons/any%28c:+c/id+eq+1%29&$top=3');
# 						});
#        </script>
#       </div>
#       <!--end #news-->
#       <div id="events">
#        <h4>
#         <a href="http://calendars.uark.edu/" title="Calendar Events">
#          EVENTS
#         </a>
#        </h4>
#        <div class="localist-widget" id="localist-widget-61149983">
#        </div>
#        <script defer="" src="https://calendars.uark.edu/widget/view?schools=uark&amp;days=31&amp;num=3&amp;container=localist-widget-61149983&amp;style=none&amp;template=template-1" type="text/javascript">
#        </script>
#       </div>
#       <!--end #events-->
#      </div>
#      <!--end #news-events-->
#      <div id="buttons">
#       <a class="apply" href="https://application.uark.edu">
#        <strong>
#         APPLY
#        </strong>
#        Online
#       </a>
#       <a class="visit" href="http://visit.uark.edu/">
#        Schedule a
#        <strong>
#         VISIT
#        </strong>
#       </a>
#       <a class="gift" href="https://onlinegiving.uark.edu/">
#        Make a
#        <strong>
#         Gift
#        </strong>
#       </a>
#      </div>
#      <!--end #buttons-->
#     </div>
#     <!--end #foot-mid-->
#     <hr/>
#     <div id="foot-bottom">
#      <ul>
#       <li>
#        <a href="http://emergency.uark.edu/">
#         Emergency Information
#        </a>
#       </li>
#       <li>
#        <a href="http://vcfa.uark.edu/2525.php">
#         Fraud Prevention
#        </a>
#       </li>
#       <li>
#        <a href="http://www.uark.edu/contact-us.php">
#         Contact Us
#        </a>
#       </li>
#       <li>
#        <a href="http://m.uark.edu">
#         Mobile
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!--end #foot-bottom-->
#    </div>
#    <!--end .wrap-->
#   </div>
#   <!--end #footer-->
#   <!--/htdig_noindex-->
#   <div aria-labeledby="dialog-title" class="screen" id="print-dialog" role="dialog">
#    <div class="print-header">
#     <h2 id="dialog-title">
#      Print Options
#     </h2>
#    </div>
#    <div class="print-body">
#     <div class="print-option">
#      <div class="option-head">
#       <a href="#" onclick="hidePrintDialog();window.print();return false">
#        Send Page to Printer
#       </a>
#      </div>
#      <p>
#       <em>
#        Print this page.
#       </em>
#      </p>
#     </div>
#     <div class="print-option">
#      <div class="option-head">
#       <a class="option-name" href="/undergraduatecatalog/collegesandschools/interdisciplinarystudies/datasciencedasc/datasciencedasc.pdf" role="button">
#        Download Page (PDF)
#       </a>
#      </div>
#      <p class="option-desc">
#       <em>
#        The PDF will include all information unique to this page.
#       </em>
#      </p>
#     </div>
#     <div class="print-option">
#      <div class="option-head">
#       <a class="option-name" href="/pdf/2022-23-undergraduate.pdf" target="_blank">
#        Undergraduate Catalog
#       </a>
#      </div>
#      <p class="option-desc">
#       <em>
#        A PDF of the entire 2022-23 Undergraduate catalog.
#       </em>
#      </p>
#     </div>
#     <div class="print-option">
#      <div class="option-head">
#       <a class="option-name" href="/pdf/2022-23-graduate.pdf" target="_blank">
#        Graduate Catalog
#       </a>
#      </div>
#      <p class="option-desc">
#       <em>
#        A PDF of the entire 2022-23 Graduate catalog.
#       </em>
#      </p>
#     </div>
#     <div class="print-option">
#      <div class="option-head">
#       <a class="option-name" href="/pdf/2022-23-law.pdf" target="_blank">
#        Law Catalog
#       </a>
#      </div>
#      <p class="option-desc">
#       <em>
#        A PDF of the entire 2022-23 Law catalog.
#       </em>
#      </p>
#     </div>
#    </div>
#    <div class="buttons clearfix">
#     <div class="cancel">
#      <a href="#" onclick="hidePrintDialog(); return false;">
#       Cancel
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# <h4><u>Accessing HTML Elements using BeautifulSoup</u></h4>
#
# Now that we have the contents of the web page, let's extract some data. First we'll extract <b><i> HTML title tag (element)</i></b> of the web page by specifying the <b><i>.title</i></b> attribute and <span class="bltn">print</span> the result. The term <b><i>HTML tag</i></b> corresponds to the <b><i>"\<title>\"</i></b> and <b><i>"\</title>\"</i></b> as the start and end tag respectively, while the term <b><i>HTML element</i></b> indicates the starting title tag, the text between the tags, and the ending title tag . If you'd like to learn more about differnt HTML elements, the <a href = "https://www.w3schools.com/html/html_elements.asp">W3 School's HTML Elements</a> is a good starting point.

# %%
# Print the title element of the web page using soup_obj.title
print(soup_obj.title)
# Out:
# <title>Data Science (DTSC) &lt; University of Arkansas</title>

# %% [markdown]
# The result of the code cell above, returns the full <b><i>HTML element</i></b> including beginning and ending <b><i>title tags</i></b>. What if you just want to return the text between the tags? In that case, you can use <b><i>.text</i></b> after the <b><i>title</i></b> title attribute. Repeat the code in the cell above, but add <b><i>.text</i></b> to the end of <b><i>title</i></b>.

# %%
# Print the contents  of the title element with .text
print(soup_obj.title.text)
# Out:
# Data Science (DTSC) < University of Arkansas

# %% [markdown]
# <h4><u>Parsing Multiple Tags in Beautiful Soup</u></h4>
#
# In the example above, you worked with a single tag. However, tags can be repeated many times on an HTML page. In the code cell below, the <b>find</b> method is used to first find the <b><i>div tag</i></b> with the unique <b><i>id</i></b> of <span class="str">textcontainer</span> and store its contents in the variable <b><i>sel_div</i></b>. Within this <b><i>div</i></b>, the <b><i>li</i></b> tag occurs multiple times within the <b><i>ul</i></b> tag. First, the <b><i>ul</i></b> tag is searched for in <b><i>sel_div</i></b> using the find method, then all instances of <b><i>li</i></b> within <b><i>ul</i></b> are searched for and returned as a <span class="bltn">list</span> stored in the variable <b><i>li_tags</i></b>. Finally each <b><i>li</i></b> element extracted is iterated over with a <span class="bltn">for</span> loop and the contents between the <b><i>li</i></b> tag printed using <span class="bltn">print</span> and <b>.text</b>.
#
# The results of <b><i>parsing</i></b> show <span class="num">6</span> skills you will learn as part of the Data Science program.

# %%
# Print some of the skills you will learn as part of the Data Science program. 
# Find the div tag with textcontainer as the id. 
sel_div = soup_obj.find(id = "textcontainer")

# The first instance of an unordered list tag within the sel_div. Within that ul tag find all li tags. 
li_tags = sel_div.find("ul").find_all("li")

# Print each item in the li_tagslist. Use a For loop
for tag in li_tags:
    print(tag.text, "\n")
# Out:
# Use and apply state-of-the-art technologies for data representation, retrieval, manipulation, storage, governance, understanding, analysis, privacy, and security.
#
# Develop descriptive, predictive and prescriptive models to abstract complex systems and organizational problems, and to use computational methods to draw data-supported conclusions.
#
# Use foundational knowledge and apply critical thinking skills to identify and solve problems, make decisions, and visualize data, all with an awareness of societal and ethical impacts.
#
# Adapt analytics concepts to interpret and communicate findings and implications to senior decision-makers.
#
# Work effectively in an interdisciplinary team and transfer findings between knowledge domains and to others with no domain experience.
#
# Communicate using technical and non-technical language in writing and verbally.

# %% [markdown]
# <h3>Working with JSON data</h3>
# In this section you will work with importing data in <b><i>JSON</i></b> format and the <b><i>requests</i></b> library.

# %% [markdown]
# <h4><u>Requesting JSON data with Requests</u></h4>
#
# Making a <b><i>request</i></b> to a server to return <b><i>JSON</i></b> is very similar to the requests you previously made. The <b><i>requests</i></b> library is used to send a <b><i>GET</i></b> request using the <b>get</b>method. The variable <span class="str">gas_url</span> stores a string specifying that the server (data.ny.gov) return the results of the specified resource (cwrk-j5nn) of the <b><i>GET</i></b> request as <b><i>JSON</i></b>.
#
# The returned result from the server is then decoded into <b><i>JSON</i></b> format using the <b>json</b> method. The request to the server is then closed using the <b>close</b> method.

# %%
# URL 
gas_url = "https://data.ny.gov/api/views/cwrk-j5nn/rows.json?accessType=DOWNLOAD"

# Open request and store response in traffic_res by using request.get(gas_url)
gas_res = requests.get(gas_url)

# Decode as json using gas_res.json()
gas_json = gas_res.json()

# Close response
gas_res.close()

# %% [markdown]
# Once the <b><i>response</i></b> to the <b><i>request</i></b> has been returned and the connection closed, the resulting <b><i>JSON</i></b> data can be worked with. A new code cell is created below to prevent running the same <b><i>GET</i></b> request multiple times unnecessarily. Let's take a look at the <span class="bltn">type</span> of data the request returned and <span class="bltn">print</span> the result. Also <span>print</span> the <b><i>JSON</i></b> data.

# %%
# # Begin a new cell to avoid accidentally making the same request multiple times. # # 

# Print the data type of gas_json. Note that it is a dictionary. 
print(type(gas_json))
# should be 'dict'

# Print traffic_json. ???????????????
# print(gas_json)
# Out:
# <class 'dict'>

# %% [markdown]
# <h4><u>Working with Requests JSON Response</u></h4>
#
# The results of the code cell above show that the decoded <b><i>JSON</i></b> data stored in the variable <b><i>gas_json</i></b> from using <b><i>Requests</i></b> <b>.json</b> method is stored as a Python <span class="bltn">dictionary</span>. Let's see what <b><i>keys</i></b> the dictionary has using the <b>.keys()</b> method.

# %%
# Print the keys in gas_json
print(gas_json.keys())
# Out:
# dict_keys(['meta', 'data'])

# %% [markdown]
# The <span class="bltn">dictionary</span> <b><i>gas_json</i></b> has two keys. The <b><i>values</i></b> for both were examined outside of this Case Study and the key <span class="str">data</span> is the one we need to use to be able to access the actual data of interest. If you're interested in seeing <b><i>values</i></b> of the <span class="str">meta</span> key you can add a Code cell below to view them.
#
# Let's see what the data <span class="bltn">type</span> that the <b><i>value</i></b> returned by the <b><i>key</i></b> <span class="span">data</span> is.

# %%
# Print the type of gas_json['data']. Note that it is a nested list
print(type(gas_json["data"]))
# Out:
# <class 'list'>

# %% [markdown]
# The value returned by the <span class="str">data</span> <b><i>key</i></b> are a <span class="bltn">list</span>. This <span class="bltn"> list</span> is actually a <span class="bltn">nested list</span> and each sublist contains a row of data in the <b><i>Estimated Gasoline Sales</i></b> dataset. This means that we can read the values in that <span class="bltn">list</span> into a <b><i>pandas DataFrame</i></b>.

# %% [markdown]
# <h4><u>Working with JSON data in Pandas</u></h4>
#
# You saw in the Code cells above that the data type of the value returned by the <span class="str">data</span> <b><i>key</i></b> is a <span class="bltn">list</span>. Using this, we can read the <span class="bltn">nested list</span> into pandas as a <b><i>DataFrame</i></b> by passing it into the <b><i>DataFrame()</i></b> constructor.
#
# For this Case Study, only three columns are of interest to us: the <i>Year</i> the estimate is being reported, the <i>County</i> it is reported from, and the <i>Estimated Sales</i> in thousands of gallons for that county for that year. The first <span class="num">8</span> columns of the <b><i>gas_df DataFrame</i></b> are removed using the <b>.drop</b> method.

# %%
# Read gas_json['data'] into a pandas DataFrame. Only keep the last 3 columns as these contain the data of interest. 
gas_df = pd.DataFrame(gas_json['data'])
gas_df.drop(gas_df.columns[0:8], axis = 1, inplace = True)

# Print/display the first 5 rows of gas_df
print(gas_df.head())

# Print the data types of the columns in gas_df
print(gas_df.dtypes)
# 'object' type refers to string type
# Out:
#      8            9       10
# 0  2016       Albany  131898
# 1  2016    Alleghany   15542
# 2  2016       Broome  100367
# 3  2016  Cattaraugus   23157
# 4  2016       Cayuga   31577
# 8     object
# 9     object
# 10    object
# dtype: object

# %% [markdown]
# The output of the Code cell above shows that the the column names are numerical values. This makes it difficult to recall what the columns are actually representing. The <b><i>data type</i></b> for all columns is <b><i>object</i></b>. This is fine for the <i>Year</i> and <i>County</i> columns, however the <i>Estimated Sales</i> column needs to be converted to <span class="num">float</span>.
#
# In the Code cell below, let's update the column names and convert the data type of the newly named <i>Estimated Sales</i> column to <span class="num">float</span>.

# %%
# Replace the column names with the values stored in the gas_col list
gas_col = ["Year", "County", "Estimated Sales"]
gas_df.columns = gas_col

# Convert Estimated Sales column to floating point values and the year column to datetime
gas_df = gas_df.astype({"Estimated Sales":float})

# Print the first 5 rows of gas_df
print(gas_df.head())

# Check the data types again to make sure Estimated Sales is now float
gas_df.dtypes
# Estimates Sales should be type 'float64'
# Out:
#    Year       County  Estimated Sales
# 0  2016       Albany         131898.0
# 1  2016    Alleghany          15542.0
# 2  2016       Broome         100367.0
# 3  2016  Cattaraugus          23157.0
# 4  2016       Cayuga          31577.0
# Year                object
# County              object
# Estimated Sales    float64
# dtype: object

# %% [markdown]
# <h4><u>Examining the Estimated Gasoline Sales Data</u></h4>
#
# At this point, the <b><i>Estimated Gasoline Sales</i></b> data has been processed into a <b><i>pandas DataFrame, gas_df,</i></b> which we can use to explore the data more.
#
# For example, let's extract a new <b><i>View</i></b> of <b><i>gas_df</i></b> called <b><i>col_co_df</i></b> which contains all rows in which <i>County</i> is <span class="op">equal to</span> <span class="str">Columbia</span>. Display the first <span class="num">5</span> rows.

# %%
# Extract all rows from gas_df where County is Columbia
col_co_df = gas_df[gas_df["County"] == "Columbia"]

# Display the first 5 results 
col_co_df.head()
# Out:
#      Year    County  Estimated Sales
# 9    2016  Columbia          40589.0
# 68   2015  Columbia          33670.0
# 127  2014  Columbia          35291.0
# 186  2013  Columbia          32661.0
# 245  2012  Columbia          33185.0

# %% [markdown]
# Now let's take a look at the <i>Estimated Sales</i> column. Calculate the <b><i>average</i></b> of the <i>Estimated Sales</i> column using <b>.mean</b>. <span class="bltn">Round</span> the result to <span class="num">2</span> decimal places and <span class="bltn">print</span>.

# %%
# Note: Code in this cell is complete. Make sure to understand the code before running. 

# Calculate the average amount of gasoline sold for Columbia county. 
# Round the result to two decimals during printing
print(round(col_co_df["Estimated Sales"].mean(),2))
# Out:
# 37244.45

# %% [markdown]
# Now let's plot the <i>Estimated Sales</i> column by year for <b><i>col_co_df</i></b>. The figure size is expanded by changing <b><i> Matplotlib's rcParams</i></b> <span class="bltn">dictionary</span> based on <a href="https://matplotlib.org/stable/tutorials/introductory/customizing.html">Matplotlib's Customizing Matplotlib with style sheets and rcParams</a> tutorial. This is not the only way the figure size can be set and throughout this course you will see multiple different ways in which <b><i>Matplotlib Visualizations</i></b> can be customized.
#
# The <b><i>title</i></b> will reference the attributes being displayed (<i>Estimated Sales per Year</i>) and the <i>County</i> it corresponds to (Columbia). In order to have the <i>Years</i> displayed in chronological order, <b><i>col_co_df</i></b> is sorted chronologically by <i>Year</i>. A <b><i>line graph</i></b> is displayed on the <b><i>figure</i></b> using <b>plt.plot</b> with the <i>Year</i> on the x-axis and the <i>Estimated Sales</i> on the y-axis. A <b><i>scatter plot</i></b> is then placed on the same <b><i>figure</i></b> using <b>plt.scatter</b> and the same arguments.

# %%
# Note: Code in this cell is complete. Make sure to understand the code before running. 

# Plot the Estimated sales for Columbia County from 1995 - 2016
# Modify the Figure to fit all years on x-axis
plt.rcParams["figure.figsize"] = (12,4)

# Create a title and labels
plt.title("Estimated Gasoline Sales for Columbia County, NY")
plt.xlabel("Year")
plt.ylabel("Thousands of Gallons")

# Sort the col_co DataFrame on year by ascending order. 
col_co_df = col_co_df.sort_values(by=["Year"])

# Plot the data using plot and scatter on the same figure. 
plt.plot(col_co_df["Year"], col_co_df["Estimated Sales"])
plt.scatter(col_co_df["Year"], col_co_df["Estimated Sales"])

# Show the plot
plt.show()

# %% [markdown]
# <h3>Working with APIs</h3>
#
# In the previous sections of this Case Study you accessed data by making <b><i>HTTP Requests</i></b> using <b><i>urllib</i></b> and <b><i>requests</i></b>. In this section you will work with the <b><i>Socrata Open Data API</i></b> to access the <b><i>Estimated Gasoline Sales</i></b> dataset in two additional formats:<b><i>csv</i><b> and as a <b><i>binary stream</i></b>.

# %% [markdown]
# <h4><u>Socrata Open Data and Estimated Gasoline Sales as CSV</u></h4>
#
# In addition to returning the <b><i>Estimated Gasoline Sales</i></b> data as <b><i>JSON</i></b>, it can also be returned in <b><i>csv</i></b> format. First we'll specify the <b><i>base_url</i></b> variable. <b><i>Base_url</i></b> contains the specified url to request data from, <span class="str">https://data.ny.gov</span>. It then specifies the resource of interest, <span class="str">cwrk-j5nn</span> which is the unique identifier for the <b><i>Estimated Gasoline Sales</i></b> dataset.

# %%
# Set the base url for all requests regarding the Estimated Gasoline Sales data through the Socrata Open Data API. 
# You will append all other parts of the request to the API to this base_url. Do not modify this variable. 
base_url = "https://data.ny.gov/resource/cwrk-j5nn"

# %% [markdown]
# Now that the <b><i>base_url</i></b> has been specified, it can be appended based on the <b><i>Socrata Open Data API</i></b>. More information can be found on the <b><i>Socrata Open Data</i></b> <a href = "https://dev.socrata.com/consumers/getting-started.html">here</a>.
#
# A <span class="bltn">try and except </span> block is created to make the request using <b><i>urllib</i></b> <b>urlopen</b> method. To specify that the response should be <b><i>csv</i></b> <span class="str">.csv</span> is appended to <b><i>base_url</i></b>. The <span class="str">?</span>character is used to <b><i>filter</i></b> the returned response. In this example, only data on Columbia county should be returned by appending <span class="str">?county=Columbia</span> after <span class="str">csv</span>. The returned response is then read into a variable <b><i>respone</i></b> using <b>.read()</b> and the request closed using <b>.close</b>.
#
# <b><i>Remember to only run the Code cell below one time to avoid making multiple repeated requests to the server. </i></b>

# %%
# Note: Code in this cell is complete. Make sure to understand the code before running. 

# Return all records in which the county is Columbia as a csv. Use urllib to do this. 
try: 
    html_page = urlopen((base_url+ ".csv?" + "county=Columbia")) 
    response = html_page.read()
    
    html_page.close()
except (HTTPError, URLError) as e: 
    print(e)

# %% [markdown]
# Let's see what the <span class="bltn">type</span> of the <b><i>response</i></b> variable is and <span class="bltn">print</span> the contents of it.

# %%
# Print the data type of the response
print(type(response))

# Print the response
print(response)
# Out:
# <class 'bytes'>
# b'"year","county","estimated_sales"\n"2016","Columbia","40589"\n"2015","Columbia","33670"\n"2014","Columbia","35291"\n"2013","Columbia","32661"\n"2012","Columbia","33185"\n"2011","Columbia","34637"\n"2010","Columbia","35873"\n"2009","Columbia","35334"\n"2008","Columbia","37524"\n"2007","Columbia","34364"\n"2006","Columbia","39965"\n"2005","Columbia","38886"\n"2004","Columbia","40381"\n"2003","Columbia","44458"\n"2002","Columbia","42020"\n"2001","Columbia","41304"\n"2000","Columbia","37236"\n"1999","Columbia","37449"\n"1998","Columbia","36004"\n"1997","Columbia","36078"\n"1996","Columbia","36916"\n"1995","Columbia","35553"\n'

# %% [markdown]
# We can see that the data <span class="bltn">type</span> of <b><i>response</i></b> is of type <b>bytes</b>. When the <b><i>response</i></b> is <span class="bltn">printed</span> the results appear similar to the <b><i>csv</i></b> format we have seen previously. Values are seperated by a <span class="str">,</span> and the end each row of the data is specified by the <span class="str">\n<span> new line character.

# %% [markdown]
# <h4><u>Reading a Bytes object into a Pandas DataFrame</u></h4>
#
# By consulting the <a href = "https://docs.python.org/3/howto/urllib2.html">Python urllib2 HOWTO Documentation</a> we can find out more information on the <b><i>response</i></b> variable's <b><i>Bytes-like</i></b> data <span class="bltn">type</span>; more specifically it is a <b><i>file-type</i></b> object.
#
# In order to be read into a <b><i>pandas DataFrame</i></b> the <b><i>file-type</i></b> Object <b><i>response</i></b> must be convereted to a <b><i>Bytes</i></b> object using Python's <b><i>BytesIO</i></b> found in the <b><i>io</i></b> module. By consulting the <a href="https://docs.python.org/3/library/io.html">Python io Documentation</a> we can see that by passing <b><i>response</i></b> as an argument to a <b><i>BytesIO</i></b> object, the returned result will be a <b><i>Bytes</i></b> object. This <b><i>BytesIO</i></b> object can then be passed to pandas <b>read_csv</b> method. The Code cell below is based on the <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html">pandas IO tools Documentation</a>, which in addition to working with <b><i>Byte</i></b> objects, shows how many different file types can be read into pandas.

# %%
from io import BytesIO

# Conversion to BytesIO based on: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
# Store the binary stream in buffer
buffer_obj = BytesIO(response)

# Read into pandas DataFrame using read_csv. This works because read_csv can take a file path or a buffer per its doc. 
col_df_new = pd.read_csv(buffer_obj)

# Close the buffer 
buffer_obj.close()

# Show the first 3 rows of the col_df_new DataFrame
col_df_new.head(3)
# Out:
#    year    county  estimated_sales
# 0  2016  Columbia            40589
# 1  2015  Columbia            33670
# 2  2014  Columbia            35291

# %% [markdown]
# <h4><u>Accessing the Socrata Open Data API with SodaPy</u></h4>
#
# Many API's have user-created libraries that help make the API easier to use. This is also the case with the <b><i>Socrata Open Data API</i></b> which has the Python library <b><i>sodapy</i></b>. More information on the <b><i>sodapy</i></b> library can be found <a href = "https://github.com/xmunoz/sodapy">here</a>.
#
# Sodapy simplifies the process of requesting data using the <b><i>Socrata Open Data</i></b> API by handling the HTTP request details. First <b><i>Socrata</i></b> needs to be <span class="bltn">imported from </span> the <b><i>sodapy</i></b> library. A <b><i>Socrata</i></b> object can then be created specifying the <b><i>base url</i></b> to connect to, in this case <span class="str">data.ny.gov</span> and the API key if needed. The <b><i>Socrata</i></b> object's <b>.get</b> method is then used to specify the specific resource (<span class="str">cwrk-j5nn</span>) and specify what to return.
#
# The code in the cell below is based on the <a href = "https://github.com/xmunoz/sodapy/tree/master/examples">sodapy library's examples found on GitHub</a>. Additional information on how sodapy can be used can be found in the <a href = "https://github.com/xmunoz/sodapy">library's GitHub</a>.

# %%
# Note: Code in this cell is complete. Make sure to understand the code before running. 
# Code based on: https://github.com/xmunoz/sodapy/tree/master/examples

# Use Socrata and sodapy to access Estimated gas sales data
from sodapy import Socrata


# Create a Socrata object specifying the url to connect to as client
client = Socrata("data.ny.gov", None)

# Specify the identifier of the Estimated gas sales data. 
# Return results where the year is after 2000, the estimated yearly sale is more than 100,000 and 
# the county name is not Statewide Total or New York State. 
results = client.get("cwrk-j5nn", where = "year > 2000 AND estimated_sales > 100000 AND (county != 'Statewide Total' AND county != 'New York State' )")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# <h4><u>Examining the Socrata Object</u></h4>
#
# Previously when the Socrata Open Data API was queried using urllib, the resulting object was returned as a <b><i>byte-like</i></b> object. The sodapy library returns the results as a <span class="bltn">list</span> instead. Similar to how <b><i>ByteIO</i></b> was used above to convert the returned response into a <b><i>Byte</i></b> object, <b><i>sodapy</i></b> has taken additional steps to convert the response to a <span class="bltn">list</span>.
#
# Let's <span class="bltn">print</span> the <span class="bltn">type</span> of the <b><i>results</i></b> variable.

# %%
# Print the data type of the returned results 
print(type(results))
# print(results)
# Out:
# <class 'list'>

# %% [markdown]
# <h4><u>Sodapy and Pandas</u></h4>
#
# Since the returned response is stored as a <span class="bltn">list</span> from using <b><i>sodapy's Socrata</i></b> object, it is easy to read <b><i>results</i></b> into a <b><i>pandas DataFrame</i></b> by using <b><i>DataFrame's</i></b> <b>from_records</b> method.

# %%
# Store the returned results list as a pandas DataFrame by using pd.DataFrame.from_records(results)
gas_results_df = pd.DataFrame.from_records(results)

# Display the first three rows.
gas_results_df.head(3)
# Out:
#    year    county estimated_sales
# 0  2013  Dutchess          100123
# 1  2007  Saratoga          100318
# 2  2016    Broome          100367

# %% [markdown]
# In the <span class="yt">Your Turn's</span> below, you will practice reading a provided <b><i>JSON</i></b> file, making HTTP requests using a library of your choice, create and parse a <b><i>BeautifulSoup</i></b> object, and work more with <b><i>sodapy</i></b> and the <b><i>Socrata Open Data</i></b> API.

# %% [markdown]
# <h3 class="yt">Your Turn: 1</h3>
# Read in <b><i>JSON</i></b> file <b><i>gas_sales_50.json</i></b> which contains the first 50 results returned from the Estimated gasoline sales dataset and store the result as a <b><i>pandas DataFrame</i></b>. <span class="bltn">Print</span> the <span class="num">last three rows</span> of the <b><i>DataFrame</i></b> you just created.

# %%
# Your Turn 1 - 
# read JSON file and store as pandas DF
gas_sales_50 = pd.read_json('gas_sales_50.json')

# print last 3 rows of new DF
print(gas_sales_50.tail(3))
# Out:
#     year    county  estimated_sales
# 47  2016     Tioga            21345
# 48  2016  Tompkins            33335
# 49  2016    Albany           131898

# %% [markdown]
# <h3 class="yt">Your Turn: 2</h3>
# Using either <b><i>urllib</i></b> or <b><i>requests</i></b> library, open https://www.google.com and store the response as a <b><i>BeautifulSoup</i></b> object. <span class="bltn">Print</span> the <b><i>title element</i></b> of the webpage.

# %%
# Your Turn 2 -

google_url = "https://www.google.com"
req = Request(google_url)
try:
    response = urlopen(req)
    html_google_page = response.read()
    response.close()

except HTTPError as e:
    print("HTTP Error: ", e.code)
except URLError as e:
    print("URL Error: ", e.reason)

req = requests.get(google_url)

# %%
html_google_page = req.text
req.close()

beau_soup_obj = BeautifulSoup(google_url, "html.parser")

# Print the title element of the web page using soup_obj.title
print(beau_soup_obj.title)
# Out:
# None
# /Users/tonibeatty/opt/miniconda3/envs/dasc2113/lib/python3.10/site-packages/bs4/__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
r = requests.get("https://www.google.com")
r.close()

soup = BeautifulSoup(r.content, 'html.parser')

print(soup.title)
# Out:
# <title>Google</title>

# %% [markdown]
# <h3 class="yt">Your Turn: 3</h3>
# Using <b><i>sodapy's Socrata</i></b> object access the <b><i>Estimated gasoline sales</i></b> dataset. Query the dataset to return records in which the <span class="str">estimated sales is < 5,000 </span>. Store the results and  <span class="bltn">print</span> the <span class="num">number of records that are returned</span>.

# %%
# Your Turn 3- 
# Create a Socrata object specifying the url to connect to as client
client = Socrata("data.ny.gov", None)

# Specify the identifier of the Estimated gas sales data. 
# Return results where the year is after 2000, the estimated yearly sale is more than 100,000 and 
# the county name is not Statewide Total or New York State. 
#results = client.get("cwrk-j5nn", where = "year > 2000 AND estimated_sales > 100000 AND (county != 'Statewide Total' AND county != 'New York State' )")
results = client.get("cwrk-j5nn", where = "estimated_sales < 5000" )

print(len(results))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 22

# %% [markdown]
# <h3 class="yt">Your Turn: 4</h3>
# Store the results from <span class="yt">Your Turn 3</span> as a <b><i>pandas DataFrame</i></b>. Using your newly created <b><i>DataFrame</i></b> display all rows that have a <span class="str">year value that occured after 2010</span>.

# %%
# Your Turn 4 - 
# Store the returned results list as a pandas DataFrame by using pd.DataFrame.from_records(results)
df1 = pd.DataFrame.from_records(results)

# Display the first three rows.
df2 = df1.loc[df1['year'] > '2010']  
print(df2)
# Out:
#     year    county estimated_sales
# 1   2012  Hamilton            2210
# 2   2013  Hamilton            2277
# 4   2011  Hamilton            2484
# 6   2014  Hamilton            2811
# 11  2016  Hamilton            3139
# 13  2015  Hamilton            3191
